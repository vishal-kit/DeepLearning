# %% [markdown]
# # MOOCS DeepLearning Lecture 1
#
# ### Vishal Gaurav

# %% [markdown]
# ### Logistic Classifier
#
# $y= wX+b$ generative equation
#
# ### Problem 1

# %%
# import modules

import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

scores = [3.0, 1.0, 0.2]

# %%
def softmax(x):
    """Compute the softmax valuses for X"""
    #x= np.asarray(x)
    return np.exp(x)/np.sum(np.exp(x),axis=0) 

print (softmax(scores))
# Out:
# [ 0.8360188   0.11314284  0.05083836]

# %%
x= np.arange(-2.0, 6.0, 0.1)
scores = np.vstack([x, np.ones_like(x), 0.2*np.ones_like(x)])

# %%
# Plot softmax curves
plt.plot(x,softmax(scores).T,linewidth=2)
plt.legend(['x','1','0.2'])
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.plot(x, softmax(scores).T, linewidth=2)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# #if you multipy the socres by 10 the probabilities get very close to 1 or 0

# %%
# when we divide the score by 10 the probability get very close to each other
# and it become like uniform distibution

# %%
# if we increase the size of our outputs the classifier becomes very sure about its prediction and 
# if we reduce the size of our outputs the classifier becomes very unsure about its predictions

# %% [markdown]
# Cross Entropy
#
# $D(S,L)=-\sum_i L_i \log(S_i)$
# * it is not symteric
#
#
# -----------------
# * we have input x
# * using the linear model $y=WX+b$ converted to LOGiT
# * logits are then fed to softmax to turn ito probabilities
# * then we are going to compare those probabilities in 1-HOT encoded lables using the cross entropy function
# ### this entire setting is often called Multinomial Logistic Classification $D(S(WX+b),L)$

# %%
x=1000000000
y= 0.000001
for i in range (1000000):
    x=x+y
    
print x
x=x-1000000000
print x
# Out:
# 1000000000.95
# 0.953674316406

# %% [markdown]
# # we always want our variable to be 0 mean and unit variance
# well conditioned problem makes it easier for the optimezers to search for an optimum solution

# %% [markdown]
# ###### if working with images
# $R = (B-128)/ 128$
#
# $G = (B-128)/ 128$
#
# $B = (B-128)/ 128$

# %% [markdown]
# we also want our weights and bais to be a good eough statring point for the gradient decent to proceed.
# draw the weights randomly from a normal distibution with mean 0 and variance $/sigma$
# sigma determines the order of magnitutde of our outputs at the initial point of optimization. it also determines the peakiness of our probability distribution. large sigma means large peaks it will be very opinionated.
# use small sigma to begin with. it will eventually gain confidence.
